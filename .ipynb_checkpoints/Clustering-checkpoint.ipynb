# %%
# importing required libraries
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('fozcoa.csv', index_col=0, delimiter=",", low_memory=False)

# %%
df.sample(5)
# Out:
#               Data        Hora Zona W1 - T1 Temp. (°C) Zona W1 - RH1 HR (%)  \
# #
# 65064   2015/04/27  04:23:00,0                   15748                61141
# 327086  2015/10/26  03:25:00,0                   17439                69739
# 347302  2015/11/09  04:21:00,0                   16939                73420
# 289222  2015/09/29  20:21:00,0                   21437                46314
# 220455  2015/08/13  02:14:00,0                   25501                43740
#
#        Zona W1 - C1A Rotação (mm/m) Zona W1 - P1 Deslocamento (mm)  \
# #
# 65064                      -41.0134                         7.2616
# 327086                     -41.0449                         7.2517
# 347302                     -41.0764                         7.2567
# 289222                     -41.0134                         7.2418
# 220455                     -40.9252                         7.2369
#
#        Zona W2 - F7 Deslocamento (mm) Zona W2 - F8 Deslocamento (mm)  \
# #
# 65064                          7.8240                         7.8211
# 327086                         7.8084                         7.8367
# 347302                         7.8162                         7.8367
# 289222                         7.8084                         7.8211
# 220455                         7.8006                         7.7899
#
#        Zona W2 - T2 Temperatura (ºC) Zona W2 - F4 Deslocamento (mm)  \
# #
# 65064                           9462                         5.5503
# 327086                         13950                         5.5503
# 347302                         12538                         5.5503
# 289222                         19300                         5.5425
# 220455                         16538                         5.5582
#
#        PtCondensação (°C)  #10597645-x
# #
# 65064                             8295
# 327086                           11871
# 347302                           12172
# 289222                            9456
# 220455                           12282

# %%
df['Hora'] = pd.to_numeric(df['Hora'],errors='coerce')
df['Data'] = pd.to_numeric(df['Data'],errors='coerce')
df['PtCondensação (°C)  #10597645-x'] = pd.to_numeric(df['PtCondensação (°C)  #10597645-x'],errors='coerce')
df['Zona W2 - F4 Deslocamento (mm)'] = pd.to_numeric(df['Zona W2 - F4 Deslocamento (mm)'],errors='coerce')
df['Zona W1 - T1 Temp. (°C)'] = pd.to_numeric(df['Zona W1 - T1 Temp. (°C)'],errors='coerce')
df['Zona W1 - RH1 HR (%)'] = pd.to_numeric(df['Zona W1 - RH1 HR (%)'],errors='coerce')
df['Zona W1 - C1A Rotação (mm/m)'] = pd.to_numeric(df['Zona W1 - C1A Rotação (mm/m)'],errors='coerce')
df['Zona W1 - P1 Deslocamento (mm)'] = pd.to_numeric(df['Zona W1 - P1 Deslocamento (mm)'],errors='coerce')
df['Zona W2 - F7 Deslocamento (mm)'] = pd.to_numeric(df['Zona W2 - F7 Deslocamento (mm)'],errors='coerce')
df['Zona W2 - F8 Deslocamento (mm)'] = pd.to_numeric(df['Zona W2 - F8 Deslocamento (mm)'],errors='coerce')
df['Zona W2 - T2 Temperatura (ºC)'] = pd.to_numeric(df['Zona W2 - T2 Temperatura (ºC)'],errors='coerce')

# %%
df = df.fillna(0)

# %%
# padronizando os dados
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)

# estatísticas dos dados padronizados
pd.DataFrame(data_scaled).describe()
# Out:
#              0         1             2             3             4   \
# count  350837.0  350837.0  3.508370e+05  3.508370e+05  3.508370e+05
# mean        0.0       0.0 -1.215476e-14 -1.018591e-14  4.878668e-15
# std         0.0       0.0  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.0       0.0 -4.802611e+00 -5.362947e+00 -7.430660e-01
# 25%         0.0       0.0 -8.914656e-01 -7.566661e-01 -1.395170e-01
# 50%         0.0       0.0 -1.306012e-02 -1.667090e-01 -3.892545e-02
# 75%         0.0       0.0  8.658097e-01  7.172188e-01  1.421393e-01
# max         0.0       0.0  1.981057e+00  2.882847e+00  1.309325e+02
#
#                  5             6             7             8             9   \
# count  3.508370e+05  3.508370e+05  3.508370e+05  3.508370e+05  3.508370e+05
# mean   1.202004e-14 -8.370093e-14  1.566700e-13 -6.119220e-14 -2.961179e-13
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.252152e+02 -1.828793e+02 -1.793573e+02 -2.986764e+00 -1.715734e+02
# 25%   -2.789336e-01 -2.265514e-01 -1.983451e-01 -7.581727e-01 -1.540146e-01
# 50%    4.616007e-02 -4.391274e-02 -1.931238e-02 -1.104205e-01  8.756510e-02
# 75%    2.692297e-01  1.387260e-01  1.597203e-01  7.175687e-01  3.291448e-01
# max    7.655164e-01  6.515193e-01  6.623891e-01  3.067776e+00  1.007426e+00
#
#                  10
# count  3.508370e+05
# mean   1.208471e-14
# std    1.000001e+00
# min   -3.666626e+00
# 25%   -6.146023e-01
# 50%    9.287762e-02
# 75%    7.287447e-01
# max    3.242115e+00

# %%
# k means using 5 clusters and k-means++ initialization
# usando 5 clusters e inicialização k-means++
kmeans = KMeans(n_jobs = -1, n_clusters = 5, init='k-means++')
kmeans.fit(data_scaled)
pred = kmeans.predict(data_scaled)

# %%
kmeans.inertia_
# Out:
# 626891.5984323367

# %%
frame = pd.DataFrame(data_scaled)
frame['cluster'] = pred
frame['cluster'].value_counts()
# Out:
# 0    164139
# 3    115676
# 1     71002
# 4        10
# 2        10
# Name: cluster, dtype: int64

# %%
frame.sample(10)
# Out:
#           0    1         2         3         4         5         6         7  \
# 222549  0.0  0.0  0.709076 -1.481767  0.242731  0.011576 -0.226551 -0.377378
# 7195    0.0  0.0 -1.954004  0.378704 -0.139517  0.679055  0.321365  0.338753
# 205767  0.0  0.0  1.384540 -1.109592 -0.038925 -0.450127 -0.226551 -0.198345
# 63304   0.0  0.0 -1.018710  1.693359 -0.139517  0.302085  0.138726  0.159720
# 323720  0.0  0.0 -0.758880  0.777988 -0.139517  0.217353 -0.043913  0.517786
# 334860  0.0  0.0 -0.952302  1.748283 -0.240108  0.302085 -0.043913  0.338753
# 282199  0.0  0.0 -0.029778 -0.146956 -0.038925  0.046160 -0.043913  0.159720
# 291563  0.0  0.0  0.020144 -0.774504 -0.038925  0.217353  0.138726  0.338753
# 207737  0.0  0.0  1.231522 -0.707285  0.242731 -0.194202 -0.226551 -0.377378
# 84356   0.0  0.0 -0.482797  1.254872 -0.240108 -0.159617  0.138726 -0.019312
#
#                8         9        10  cluster
# 222549  0.138640  0.573822 -0.610797        0
# 7195   -1.454506  0.087565 -2.266888        3
# 205767  1.225568 -0.154015  0.765762        0
# 63304  -1.047556 -0.395594  0.097375        1
# 323720 -0.539556  0.329145 -0.255154        1
# 334860 -0.956385  0.573822  0.232644        1
# 282199  0.179125  0.329145 -0.085982        0
# 291563  0.049574  0.329145 -0.677566        3
# 207737 -0.039492  0.765847  1.039067        0
# 84356   1.324836 -0.637174  0.524285        1

# %%
X = df[["Zona W1 - T1 Temp. (°C)","Zona W1 - P1 Deslocamento (mm)"]]
#Visualise data points
plt.scatter(X["Zona W1 - P1 Deslocamento (mm)"],X["Zona W1 - T1 Temp. (°C)"],c='black')
plt.xlabel('AnnualIncome')
plt.ylabel('Loan Amount (In Thousands)')
plt.show()

# %%
# Step 1 and 2 - Choose the number of clusters (k) and select random centroid for each cluster

#number of clusters
K=5

# Select random observation as centroids
Centroids = (X.sample(n=K))
plt.scatter(X["Zona W1 - T1 Temp. (°C)"],X["Zona W1 - P1 Deslocamento (mm)"],c='black')
plt.scatter(Centroids["Zona W1 - T1 Temp. (°C)"],Centroids["Zona W1 - P1 Deslocamento (mm)"],c='red')
plt.xlabel('Zona W1 - T1 Temp. (°C)')
plt.ylabel('Zona W1 - P1 Deslocamento (mm)')
plt.show()
